# %%
interface_name = 'ge-0/0/1'
print (interface_name)
# Out:
# ge-0/0/1

# %% [markdown]
# ### Python List

# %%
protocols = ['mpls', 'bgp', 'isis', 'ospf']

# %%
for prot in protocols:
    print (prot)
# Out:
# mpls
# bgp
# isis
# ospf

# %% [markdown]
# ### Python Dictionary

# %%
data = {'company': 'Juniper',
       'ceo': 'Rami Rahim',
       'domain': 'Networking'}

print (data)
# Out:
# {'company': 'Juniper', 'ceo': 'Rami Rahim', 'domain': 'Networking'}

# %%
for k,v in data.items():
    print (k, ' -> ', v)
# Out:
# company  ->  Juniper
# ceo  ->  Rami Rahim
# domain  ->  Networking

# %%
data = {'iface_name':'ge-0/0/1', 'vlan_name':'200'}
print (data)
# Out:
# {'iface_name': 'ge-0/0/1', 'vlan_name': '200'}

# %% [markdown]
# # YAML
#
# ### YAML is a human friendly data serialization standard for all programming languages. It is ideal for storing object tree.
#
# ### Python programmers are generally big fans of YAML, because of the use of indentation, rather than bracketed syntax, to indicate levels.
#
# ### A markup language is a language that annotates text so that the computer can manipulate the text.

# %% [markdown]
# ```yaml
# ---
# # An employee record
# name: Example Developer
# job: Developer
# skill: Elite
# employed: True
# foods:
#     - Apple
#     - Orange
#     - Strawberry
#     - Mango
# languages:
#     ruby: Elite
#     python: Elite
#     dotnet: Lame
# ```

# %% [markdown]
# #### Thumb rule to write YAML: Proper indentation.

# %% [markdown]
# So what are the benefits of YAML:
#
# Portable between programming languages:
#
# YAML emitters and parsers for many popular languages written in the pure native language itself exist, making it portable in a self-contained manner.
# YAML representations of application information will be consistent and portable between various programming environments
#
# Well known libraries to play with YAML in programming language:
# C/C++:
# - libyaml       	# "C" Fast YAML 1.1
# Ruby:
# - Psych         	# libyaml wrapper (in Ruby core for 1.9.2)
# - RbYaml        	# YAML 1.1 (PyYaml Port) binding
# Python:
# - PyYaml        	# YAML 1.1, pure python and libyaml binding
# - PySyck        	# YAML 1.0, syck binding
# Java:
# - JvYaml        	# Java port of RbYaml
# Perl Modules:
# - YAML          	# Pure Perl YAML Module
# - YAML::Syck    	# Binding to libsyck
# - PlYaml        	# Perl port of PyYaml implementation
# PHP:
# - php-yaml      	# libyaml bindings (YAML 1.1)
# - syck          	# syck bindings (YAML 1.0)

# %% [markdown]
# ### Another example

# %% [markdown]
# ```yaml
# ---
# name: Juniper Networks
# CEO: Rami Rahim
# Headquarter: Sunnyvale
# Development:
#     - Sunnyvale
#     - Bangalore
#     - Beijing
# Sales:
#     - Sydeny
#     - Mumbai
# ```

# %%
import yaml

data = """
---
name: Juniper Networks 
CEO: Rami Rahim
Headquarter: Sunnyvale
Development:     
    - Sunnyvale
    - Bangalore
    - Beijing
Sales:     
    - Sydeny
    - Mumbai
"""

yaml.load(data)
# Out:
# {'name': 'Juniper Networks',
#  'CEO': 'Rami Rahim',
#  'Headquarter': 'Sunnyvale',
#  'Development': ['Sunnyvale', 'Bangalore', 'Beijing'],
#  'Sales': ['Sydeny', 'Mumbai']}

# %%
data = """
---
-
    - pineapple   
    - coconut 
-
    - umbrella   
    - raincoat
"""
yaml.load(data)
# Out:
# [['pineapple', 'coconut'], ['umbrella', 'raincoat']]

# %%
data = """
---
Joey:   
    age: 22   
    sex: M 
Laura:   
    age: 24   
    sex: F
"""
yaml.load(data)
# Out:
# {'Joey': {'age': 22, 'sex': 'M'}, 'Laura': {'age': 24, 'sex': 'F'}}

# %%
data = """
---
receipt:     Oz-Ware Purchase Invoice
date:        2012-08-06
customer:
    first_name:   Dorothy
    family_name:  Gale

items:
    - part_no:   A4786
      descrip:   Water Bucket (Filled)
      price:     1.47
      quantity:  4

    - part_no:   E1628
      descrip:   High Heeled "Ruby" Slippers
      size:      8
      price:     133.7
      quantity:  1

bill-to:  &id001
    street: |
            123 Tornado Alley
            Suite 16
    city:   East Centerville
    state:  KS

ship-to:  *id001

specialDelivery:  >
    Follow the Yellow Brick
    Road to the Emerald City.
    Pay no attention to the
    man behind the curtain.
...
"""
yaml.load(data)
# Out:
# {'receipt': 'Oz-Ware Purchase Invoice',
#  'date': datetime.date(2012, 8, 6),
#  'customer': {'first_name': 'Dorothy', 'family_name': 'Gale'},
#  'items': [{'part_no': 'A4786',
#    'descrip': 'Water Bucket (Filled)',
#    'price': 1.47,
#    'quantity': 4},
#   {'part_no': 'E1628',
#    'descrip': 'High Heeled "Ruby" Slippers',
#    'size': 8,
#    'price': 133.7,
#    'quantity': 1}],
#  'bill-to': {'street': '123 Tornado Alley\nSuite 16\n',
#   'city': 'East Centerville',
#   'state': 'KS'},
#  'ship-to': {'street': '123 Tornado Alley\nSuite 16\n',
#   'city': 'East Centerville',
#   'state': 'KS'},
#  'specialDelivery': 'Follow the Yellow Brick Road to the Emerald City. Pay no attention to the man behind the curtain.\n'}

# %%
print('123 Tornado Alley\nSuite 16\n')
# Out:
# 123 Tornado Alley
# Suite 16

# %%
data = """
---
- step:  &id001                  # defines anchor label &id001
    instrument:      Lasik 2000
    pulseEnergy:     5.4
    pulseDuration:   12
    repetition:      1000
    spotSize:        1mm

- step: &id002
    instrument:      Lasik 2000
    pulseEnergy:     5.0
    pulseDuration:   10
    repetition:      500
    spotSize:        2mm
- step: *id001                   # refers to the first step (with anchor &id001)
- step: *id002                   # refers to the second step
- step: 
    <<: *id001
    spotSize: 2mm             # redefines just this key, refers rest from &id001
"""
yaml.load(data)

# %%
yaml.parse?

# %% [markdown]
# ## Jinja2

# %% [markdown]
# ### Junos sample config

# %%
import os
cwd = os.getcwd()
print (cwd)
# Out:
# /Users/nitinkr/Coding/PythonTraining/templates

# %%
from jinja2 import Template
t = Template("Hello {{ data }}!!")
print (t.render(data='xyz'))
# Out:
# Hello xyz!!

# %% [markdown]
# ```text
# interfaces {
#     interface ge-0/0/1 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 200;
#                }
#            }
#        }
#     }
# }
# ```

# %% [markdown]
# ### jinja2 template

# %% [markdown]
# ```jinja2
# interfaces {
#     interface {{ iface_name }} {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member {{ vlan_name }};
#                }
#            }
#        }
#     }
# }
# ```

# %%
import jinja2
template = """interfaces {
    interface {{ iface_name }} {
        unit 0 {
            family ethernet-switching {
                port-mode access;
                replace:
                vlan {
                    member {{ vlan_name }};
               }
           }
       }
    } 
}"""
tmpl = jinja2.Template(template)
conf = tmpl.render(iface_name='ge-1/1/2', vlan_name='200')
print (conf)
# Out:
# interfaces {
#     interface ge-1/1/2 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 200;
#                }
#            }
#        }
#     }
# }

# %%
import jinja2
template = """interfaces {
    interface {{ iface_name }} {
        unit 0 {
            family ethernet-switching {
                port-mode access;
                replace:
                vlan {
                    member {{ vlan_name }};
               }
           }
       }
    } 
}"""
tmpl = jinja2.Template(template)
conf = tmpl.render({'iface_name':'ge-0/0/1', 'vlan_name':'200'})
print (conf)
# Out:
# interfaces {
#     interface ge-0/0/1 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 200;
#                }
#            }
#        }
#     }
# }

# %%
import jinja2

# tmpl = jinja2.Template(open('/Users/nitinkr/demos/PyEZ/templates/1_temp.j2').read())

loader = jinja2.FileSystemLoader(cwd)
jenv = jinja2.Environment(loader=loader, trim_blocks=True, lstrip_blocks=True)
tmpl = jenv.get_template('1_temp.j2')
conf = tmpl.render(iface_name='ge-0/0/5', vlan_name='300')
print (conf)
# Out:
# interfaces {
#     interface ge-0/0/5 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
# }

# %% [markdown]
# #### To know more about trim_blocks, lstrip_blocks
#
# http://jinja.pocoo.org/docs/dev/templates/#whitespace-control

# %%
jinja2.Environment?

# %% [markdown]
# ### Loop inside Jinja Template
#
# ```jinja2
# interfaces {
#     {% for item in interfaces %}
#     {{ item }} {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member {{ vlan_name }};
#                }
#            }
#        }
#     } {% endfor %}
# }
# ```

# %%
import jinja2
template = """interfaces {
    {% for item in interfaces %}
    ge-0/1/{{ item }} {
        unit 0 {
            family ethernet-switching {
                port-mode access;
                replace:
                vlan {
                    member {{ vlan_name }};
               }
           }
       } 
    } {% endfor %}    
}"""
tmpl = jinja2.Template(template)
conf = tmpl.render(interfaces=range(100), vlan_name='300')
print (conf)
# Out:
# interfaces {
#
#     ge-0/1/0 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/1 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/2 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/3 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/4 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/5 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/6 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/7 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/8 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/9 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/10 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/11 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/12 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/13 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/14 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/15 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/16 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/17 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/18 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/19 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/20 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/21 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/22 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/23 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/24 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/25 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/26 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/27 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/28 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/29 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/30 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/31 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/32 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/33 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/34 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/35 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/36 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/37 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/38 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/39 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/40 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/41 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/42 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/43 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/44 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/45 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/46 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/47 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/48 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/49 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/50 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/51 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/52 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/53 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/54 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/55 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/56 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/57 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/58 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/59 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/60 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/61 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/62 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/63 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/64 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/65 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/66 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/67 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/68 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/69 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/70 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/71 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/72 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/73 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/74 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/75 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/76 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/77 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/78 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/79 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/80 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/81 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/82 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/83 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/84 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/85 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/86 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/87 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/88 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/89 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/90 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/91 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/92 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/93 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/94 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/95 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/96 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/97 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/98 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/1/99 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode access;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
# }

# %% [markdown]
# ### Filter in Template

# %%
loader = jinja2.FileSystemLoader(cwd)
jenv = jinja2.Environment(loader=loader, trim_blocks=True, lstrip_blocks=True)

# %%
import jinja2
template = """interfaces {
    {% for item in interfaces %}
    {{ item }} {
        unit 0 {
            family ethernet-switching {
                port-mode {{ mode | upper }};
                replace:
                vlan {
                    member {{ vlan_name }};
               }
           }
       } 
    } {% endfor %}    
}"""
tmpl = jinja2.Template(template)
conf = tmpl.render(interfaces=['ge-0/0/1', 'ge-0/0/2'], vlan_name='300', mode='access')
print (conf)
# Out:
# interfaces {
#
#     ge-0/0/1 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode ACCESS;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
#     ge-0/0/2 {
#         unit 0 {
#             family ethernet-switching {
#                 port-mode ACCESS;
#                 replace:
#                 vlan {
#                     member 300;
#                }
#            }
#        }
#     }
# }

# %%
jenv.filters
# Out:
# {'abs': <function abs(x, /)>,
#  'attr': <function jinja2.filters.do_attr(environment, obj, name)>,
#  'batch': <function jinja2.filters.do_batch(value, linecount, fill_with=None)>,
#  'capitalize': <function jinja2.filters.do_capitalize(s)>,
#  'center': <function jinja2.filters.do_center(value, width=80)>,
#  'count': <function len(obj, /)>,
#  'd': <function jinja2.filters.do_default(value, default_value='', boolean=False)>,
#  'default': <function jinja2.filters.do_default(value, default_value='', boolean=False)>,
#  'dictsort': <function jinja2.filters.do_dictsort(value, case_sensitive=False, by='key', reverse=False)>,
#  'e': <function markupsafe._speedups.escape>,
#  'escape': <function markupsafe._speedups.escape>,
#  'filesizeformat': <function jinja2.filters.do_filesizeformat(value, binary=False)>,
#  'first': <function jinja2.filters.do_first(environment, seq)>,
#  'float': <function jinja2.filters.do_float(value, default=0.0)>,
#  'forceescape': <function jinja2.filters.do_forceescape(value)>,
#  'format': <function jinja2.filters.do_format(value, *args, **kwargs)>,
#  'groupby': <function jinja2.filters.do_groupby(environment, value, attribute)>,
#  'indent': <function jinja2.filters.do_indent(s, width=4, first=False, blank=False, indentfirst=None)>,
#  'int': <function jinja2.filters.do_int(value, default=0, base=10)>,
#  'join': <function jinja2.filters.do_join(eval_ctx, value, d='', attribute=None)>,
#  'last': <function jinja2.filters.do_last(environment, seq)>,
#  'length': <function len(obj, /)>,
#  'list': <function jinja2.filters.do_list(value)>,
#  'lower': <function jinja2.filters.do_lower(s)>,
#  'map': <function jinja2.filters.do_map(*args, **kwargs)>,
#  'min': <function jinja2.filters.do_min(environment, value, case_sensitive=False, attribute=None)>,
#  'max': <function jinja2.filters.do_max(environment, value, case_sensitive=False, attribute=None)>,
#  'pprint': <function jinja2.filters.do_pprint(value, verbose=False)>,
#  'random': <function jinja2.filters.do_random(context, seq)>,
#  'reject': <function jinja2.filters.do_reject(*args, **kwargs)>,
#  'rejectattr': <function jinja2.filters.do_rejectattr(*args, **kwargs)>,
#  'replace': <function jinja2.filters.do_replace(eval_ctx, s, old, new, count=None)>,
#  'reverse': <function jinja2.filters.do_reverse(value)>,
#  'round': <function jinja2.filters.do_round(value, precision=0, method='common')>,
#  'safe': <function jinja2.filters.do_mark_safe(value)>,
#  'select': <function jinja2.filters.do_select(*args, **kwargs)>,
#  'selectattr': <function jinja2.filters.do_selectattr(*args, **kwargs)>,
#  'slice': <function jinja2.filters.do_slice(value, slices, fill_with=None)>,
#  'sort': <function jinja2.filters.do_sort(environment, value, reverse=False, case_sensitive=False, attribute=None)>,
#  'string': <function markupsafe._speedups.soft_unicode>,
#  'striptags': <function jinja2.filters.do_striptags(value)>,
#  'sum': <function jinja2.filters.do_sum(environment, iterable, attribute=None, start=0)>,
#  'title': <function jinja2.filters.do_title(s)>,
#  'trim': <function jinja2.filters.do_trim(value)>,
#  'truncate': <function jinja2.filters.do_truncate(env, s, length=255, killwords=False, end='...', leeway=None)>,
#  'unique': <function jinja2.filters.do_unique(environment, value, case_sensitive=False, attribute=None)>,
#  'upper': <function jinja2.filters.do_upper(s)>,
#  'urlencode': <function jinja2.filters.do_urlencode(value)>,
#  'urlize': <function jinja2.filters.do_urlize(eval_ctx, value, trim_url_limit=None, nofollow=False, target=None, rel=None)>,
#  'wordcount': <function jinja2.filters.do_wordcount(s)>,
#  'wordwrap': <function jinja2.filters.do_wordwrap(environment, s, width=79, break_long_words=True, wrapstring=None)>,
#  'xmlattr': <function jinja2.filters.do_xmlattr(_eval_ctx, d, autospace=True)>,
#  'tojson': <function jinja2.filters.do_tojson(eval_ctx, value, indent=None)>}

# %%
from bracket_expansion import bracket_expansion
jenv.filters['bracket_expansion']=bracket_expansion
for i in bracket_expansion('ge-0/0/[0-5]'):
    print (i)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-0d77946871ba> in <module>
# ----> 1 from bracket_expansion import bracket_expansion
#       2 jenv.filters['bracket_expansion']=bracket_expansion
#       3 for i in bracket_expansion('ge-0/0/[0-5]'):
#       4     print (i)
#
# ModuleNotFoundError: No module named 'bracket_expansion'

# %%
import jinja2
template = """interfaces {
    {% for item in iface_pattern | bracket_expansion %}
    {{ item }} {
        unit 0 {
            family ethernet-switching {
                port-mode access;
                replace:
                vlan {
                    member {{ vlan_name }};
               }
           }
       } 
    } {% endfor %}    
}"""
loader = jinja2.FileSystemLoader(cwd)
jenv = jinja2.Environment(loader=loader, trim_blocks=True, lstrip_blocks=True)
jenv.filters['bracket_expansion']=bracket_expansion
tmpl = jenv.get_template('filter.j2')
conf = tmpl.render(iface_pattern='ge-0/0/[0-10]', vlan_name='300')
print conf

# %% [markdown]
# ### Include directive
# #### To create Modular template

# %%
from glob import glob
print glob(cwd+'/sshkeys/*.pub')

# %%
from os.path import basename, splitext
print [basename(i) for i in glob(cwd+'/sshkeys/*.pub')]
print [splitext(basename(i))[0] for i in glob(cwd+'/sshkeys/*.pub')]

# %%
def basefilename(name):
    return splitext(basename(name))[0]

# basefilename = lambda name: splitext(basename(name))[0]

# %% [markdown]
# ```jinja2
# system {
#     login {
#         {% for ssh_pub in sshkeyfiles %}
#         user {{ ssh_pub | basefilename }} {
#             authentication {
#                 ssh-rsa "{% include ssh_pub %}";
#             }
#         }
#         {% endfor %}
#     }
# }
# ```

# %%
import jinja2

loader = jinja2.FileSystemLoader(cwd)
jenv = jinja2.Environment(loader=loader, trim_blocks=True, lstrip_blocks=True)
jenv.filters['basefilename']=basefilename
tmpl = jenv.get_template('users.j2')
print tmpl.render(sshkeyfiles=glob('sshkeys/*.pub'))
# Out:
#   File "<ipython-input-40-eb969155cc2c>", line 7
#     print tmpl.render(sshkeyfiles=glob('sshkeys/*.pub'))
#              ^
# SyntaxError: invalid syntax

# %%
with open(os.path.join(cwd, 'main.j2')) as fp:
    print fp.read()
# Out:
#   File "<ipython-input-41-891f307336ca>", line 2
#     print fp.read()
#            ^
# SyntaxError: invalid syntax

# %%
main = jenv.get_template('main.j2')
print main.render(sshkeyfiles=glob('sshkeys/*.pub'), interfaces=['ge-0/0/1', 'ge-0/0/2'], family='mpls', description='MPLS interface')
# Out:
#   File "<ipython-input-42-4612d07f9fb0>", line 2
#     print main.render(sshkeyfiles=glob('sshkeys/*.pub'), interfaces=['ge-0/0/1', 'ge-0/0/2'], family='mpls', description='MPLS interface')
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### if/then/else directives

# %%
import csv
vlans = csv.DictReader(open(os.path.join(cwd,'vlans.csv')))
print vlans
for i in vlans:
    print i,','
# Out:
#   File "<ipython-input-43-5234e4c26eba>", line 3
#     print vlans
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(vlans)?

# %%
import jinja2

vlans = csv.DictReader(open(os.path.join(cwd,'vlans.csv')))
loader = jinja2.FileSystemLoader(cwd)
jenv = jinja2.Environment(loader=loader, trim_blocks=True, lstrip_blocks=True)
tmpl = jenv.get_template('main_vlans.conf')
print tmpl.render(vlan_list=vlans)
# Out:
#   File "<ipython-input-44-fb78731ab5a7>", line 7
#     print tmpl.render(vlan_list=vlans)
#              ^
# SyntaxError: invalid syntax

# %%
vlans = csv.DictReader(open(os.path.join(cwd,'vlans.csv')))
print tmpl.render(vlan_list=vlans, state='absent')
# Out:
#   File "<ipython-input-45-bffc4d8cecf2>", line 2
#     print tmpl.render(vlan_list=vlans, state='absent')
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### This presentation from AnsibleFest San Francisco 2015 focused on how Riot Games utilizes Ansible, Config templates  and Juniper’s Py-EZ.

# %%
from IPython.display import HTML
HTML('<iframe src="http://fast.wistia.net/embed/iframe/qkho0rgeyc" width=900 height=500></iframe>')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('PSgSjTeqRX0', start=450, width=900, height=500)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Gk5KKozJmz8', start=156, width=900, height=500)
